# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000, size=2000)
lngs = np.random.uniform(low=-180,high=180,size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

#identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # if the city is unique, the we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# print the city count to confirm the sufficient count
len(cities)
# Out:
# 754

# %%
#import the request library
import requests as req

#import the api key
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#import dependencies
from datetime import datetime

# %%
#create an empty list to hold the weather data
city_data = []
#print the beginning of the logging
print("Beginning Data Retrieval")
print("------------------------")

#create counters
record_count = 1
set_count = 1

#loop through all the cities in our list
#for i in range (len(cities)):
for i, city in enumerate(cities): 

    #group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i>50):
        set_count += 1
        record_count = 1
    
    #create endpoint URL with each city
    #city_url = url + "&q=" + cities[i]
    city_url = url + "&q=" + city.replace(" ","+")
    
    #log the url, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 to the record count
    record_count += 1

    
#Run an API request for each of the cities
    try:
        #parse the json and retrieve data
        city_weather = req.get(city_url).json()
        #parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        #convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%y-%m-%d %H:%M:%S')
        
        #append the city informatio into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          #"Date": city_date,
                         "Current Description":city_description})
    #if an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    

print("----------------------------")
print("Data Retrieval Complete")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | mongo
# Processing Record 3 of Set 1 | nikolskoye
# Processing Record 4 of Set 1 | mar del plata
# Processing Record 5 of Set 1 | beya
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | kavieng
# Processing Record 10 of Set 1 | coihaique
# Processing Record 11 of Set 1 | port blair
# Processing Record 12 of Set 1 | caravelas
# Processing Record 13 of Set 1 | chingola
# Processing Record 14 of Set 1 | omboue
# Processing Record 15 of Set 1 | yarkovo
# Processing Record 16 of Set 1 | gizo
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | kaitangata
# Processing Record 20 of Set 1 | belfort
# Processing Record 21 of Set 1 | saskylakh
# Processing Record 22 of Set 1 | piney green
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | gjusvik
# City not found. Skipping...
# Processing Record 25 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 1 | cidreira
# Processing Record 27 of Set 1 | jurm
# Processing Record 28 of Set 1 | puerto madero
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | champerico
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | salalah
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | sapouy
# Processing Record 38 of Set 1 | ribas do rio pardo
# Processing Record 39 of Set 1 | arraial do cabo
# Processing Record 40 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 1 | mandalgovi
# Processing Record 42 of Set 1 | atikokan
# Processing Record 43 of Set 1 | liverpool
# Processing Record 44 of Set 1 | yar-sale
# Processing Record 45 of Set 1 | sawakin
# Processing Record 46 of Set 1 | iranshahr
# Processing Record 47 of Set 1 | llangefni
# Processing Record 48 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 1 | mahebourg
# Processing Record 50 of Set 1 | nemuro
# Processing Record 51 of Set 1 | rikitea
# Processing Record 52 of Set 1 | victoria
# Processing Record 53 of Set 1 | wanderlandia
# City not found. Skipping...
# Processing Record 54 of Set 1 | santa maria
# Processing Record 55 of Set 1 | jamestown
# Processing Record 56 of Set 1 | chuy
# Processing Record 57 of Set 1 | hermanus
# Processing Record 58 of Set 1 | texarkana
# Processing Record 59 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 60 of Set 1 | tasiilaq
# Processing Record 61 of Set 1 | coquimbo
# Processing Record 62 of Set 1 | karratha
# Processing Record 63 of Set 1 | faanui
# Processing Record 64 of Set 1 | dong hoi
# Processing Record 65 of Set 1 | chaiya
# Processing Record 66 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 67 of Set 1 | atuona
# Processing Record 68 of Set 1 | hobart
# Processing Record 69 of Set 1 | cotonou
# Processing Record 70 of Set 1 | college
# Processing Record 71 of Set 1 | bandarbeyla
# Processing Record 72 of Set 1 | port elizabeth
# Processing Record 73 of Set 1 | vanavara
# Processing Record 74 of Set 1 | salinopolis
# Processing Record 75 of Set 1 | olafsvik
# Processing Record 76 of Set 1 | sinnamary
# Processing Record 77 of Set 1 | kruisfontein
# Processing Record 78 of Set 1 | puerto ayora
# Processing Record 79 of Set 1 | umm lajj
# Processing Record 80 of Set 1 | sawtell
# Processing Record 81 of Set 1 | houlton
# Processing Record 82 of Set 1 | bathsheba
# Processing Record 83 of Set 1 | san jose
# Processing Record 84 of Set 1 | cortez
# Processing Record 85 of Set 1 | castrillon
# Processing Record 86 of Set 1 | huarmey
# Processing Record 87 of Set 1 | marsa matruh
# Processing Record 88 of Set 1 | adrar
# Processing Record 89 of Set 1 | airai
# Processing Record 90 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 91 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 92 of Set 1 | boguchany
# Processing Record 93 of Set 1 | porto novo
# Processing Record 94 of Set 1 | shreveport
# Processing Record 95 of Set 1 | kalnibolotskaya
# Processing Record 96 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 97 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 98 of Set 1 | lodwar
# Processing Record 99 of Set 1 | klaksvik
# Processing Record 100 of Set 1 | yulara
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | zlobin
# Processing Record 4 of Set 2 | longyearbyen
# Processing Record 5 of Set 2 | amapa
# Processing Record 6 of Set 2 | beringovskiy
# Processing Record 7 of Set 2 | praia
# Processing Record 8 of Set 2 | poum
# Processing Record 9 of Set 2 | bac lieu
# Processing Record 10 of Set 2 | ulaangom
# Processing Record 11 of Set 2 | torbay
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | lebu
# Processing Record 14 of Set 2 | sola
# Processing Record 15 of Set 2 | sioux lookout
# Processing Record 16 of Set 2 | zhigansk
# Processing Record 17 of Set 2 | suleja
# Processing Record 18 of Set 2 | necochea
# Processing Record 19 of Set 2 | aklavik
# Processing Record 20 of Set 2 | wulanhaote
# City not found. Skipping...
# Processing Record 21 of Set 2 | vanimo
# Processing Record 22 of Set 2 | sao joao da barra
# Processing Record 23 of Set 2 | nishihara
# Processing Record 24 of Set 2 | saint george
# Processing Record 25 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 2 | alice springs
# Processing Record 27 of Set 2 | luderitz
# Processing Record 28 of Set 2 | vaini
# Processing Record 29 of Set 2 | cherskiy
# Processing Record 30 of Set 2 | havelock
# Processing Record 31 of Set 2 | ancud
# Processing Record 32 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 2 | vila franca do campo
# Processing Record 34 of Set 2 | pastavy
# Processing Record 35 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 2 | jibuti
# Processing Record 37 of Set 2 | tiksi
# Processing Record 38 of Set 2 | bogo
# Processing Record 39 of Set 2 | pevek
# Processing Record 40 of Set 2 | chapais
# Processing Record 41 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 2 | baruun-urt
# Processing Record 43 of Set 2 | axim
# Processing Record 44 of Set 2 | hamilton
# Processing Record 45 of Set 2 | thompson
# Processing Record 46 of Set 2 | geraldton
# Processing Record 47 of Set 2 | margate
# Processing Record 48 of Set 2 | velsk
# Processing Record 49 of Set 2 | hilo
# Processing Record 50 of Set 2 | klyuchevskiy
# Processing Record 1 of Set 3 | saint-philippe
# Processing Record 2 of Set 3 | bethel
# Processing Record 3 of Set 3 | fortuna
# Processing Record 4 of Set 3 | marolambo
# Processing Record 5 of Set 3 | ribeira grande
# Processing Record 6 of Set 3 | la ronge
# Processing Record 7 of Set 3 | adelaide
# Processing Record 8 of Set 3 | dauphin
# Processing Record 9 of Set 3 | barrow
# Processing Record 10 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 3 | komsomolskiy
# Processing Record 12 of Set 3 | tuatapere
# Processing Record 13 of Set 3 | soyo
# Processing Record 14 of Set 3 | salsomaggiore terme
# Processing Record 15 of Set 3 | yanchukan
# City not found. Skipping...
# Processing Record 16 of Set 3 | broken hill
# Processing Record 17 of Set 3 | kabinda
# Processing Record 18 of Set 3 | georgetown
# Processing Record 19 of Set 3 | penzance
# Processing Record 20 of Set 3 | cabo san lucas
# Processing Record 21 of Set 3 | miguel calmon
# Processing Record 22 of Set 3 | teknaf
# Processing Record 23 of Set 3 | sumenep
# Processing Record 24 of Set 3 | burica
# City not found. Skipping...
# Processing Record 25 of Set 3 | osa
# Processing Record 26 of Set 3 | inta
# Processing Record 27 of Set 3 | gandai
# Processing Record 28 of Set 3 | norman wells
# Processing Record 29 of Set 3 | provideniya
# Processing Record 30 of Set 3 | dunedin
# Processing Record 31 of Set 3 | shahr-e kord
# Processing Record 32 of Set 3 | chokurdakh
# Processing Record 33 of Set 3 | kahta
# Processing Record 34 of Set 3 | idritsa
# Processing Record 35 of Set 3 | wadi maliz
# Processing Record 36 of Set 3 | thunder bay
# Processing Record 37 of Set 3 | constitucion
# Processing Record 38 of Set 3 | terrell
# Processing Record 39 of Set 3 | luwero
# Processing Record 40 of Set 3 | marrakesh
# Processing Record 41 of Set 3 | ocos
# Processing Record 42 of Set 3 | najran
# Processing Record 43 of Set 3 | butaritari
# Processing Record 44 of Set 3 | severo-kurilsk
# Processing Record 45 of Set 3 | nanortalik
# Processing Record 46 of Set 3 | maniitsoq
# Processing Record 47 of Set 3 | matagami
# Processing Record 48 of Set 3 | larsnes
# Processing Record 49 of Set 3 | iqaluit
# Processing Record 50 of Set 3 | peniche
# Processing Record 1 of Set 4 | lagoa
# Processing Record 2 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 3 of Set 4 | richards bay
# Processing Record 4 of Set 4 | guerrero negro
# Processing Record 5 of Set 4 | villa union
# Processing Record 6 of Set 4 | berwick
# Processing Record 7 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 8 of Set 4 | hasaki
# Processing Record 9 of Set 4 | cairns
# Processing Record 10 of Set 4 | panalingaan
# Processing Record 11 of Set 4 | khatassy
# Processing Record 12 of Set 4 | vila
# Processing Record 13 of Set 4 | okhotsk
# Processing Record 14 of Set 4 | escanaba
# Processing Record 15 of Set 4 | safaqis
# City not found. Skipping...
# Processing Record 16 of Set 4 | quelimane
# Processing Record 17 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 4 | vao
# Processing Record 19 of Set 4 | maun
# Processing Record 20 of Set 4 | faya
# Processing Record 21 of Set 4 | aykhal
# Processing Record 22 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 4 | port hardy
# Processing Record 24 of Set 4 | marsh harbour
# Processing Record 25 of Set 4 | le vauclin
# Processing Record 26 of Set 4 | cassilandia
# Processing Record 27 of Set 4 | howard springs
# Processing Record 28 of Set 4 | aksarka
# Processing Record 29 of Set 4 | ulladulla
# Processing Record 30 of Set 4 | noumea
# Processing Record 31 of Set 4 | sakaiminato
# Processing Record 32 of Set 4 | tessalit
# Processing Record 33 of Set 4 | andrelandia
# Processing Record 34 of Set 4 | bam
# Processing Record 35 of Set 4 | kushiro
# Processing Record 36 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 4 | abnub
# Processing Record 38 of Set 4 | ahipara
# Processing Record 39 of Set 4 | port moresby
# Processing Record 40 of Set 4 | santarem
# Processing Record 41 of Set 4 | punta de piedra
# Processing Record 42 of Set 4 | rafaela
# Processing Record 43 of Set 4 | storm lake
# Processing Record 44 of Set 4 | upernavik
# Processing Record 45 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 4 | san cristobal
# Processing Record 47 of Set 4 | sakakah
# Processing Record 48 of Set 4 | zabid
# Processing Record 49 of Set 4 | bengkulu
# Processing Record 50 of Set 4 | tezu
# Processing Record 1 of Set 5 | horsham
# Processing Record 2 of Set 5 | nenjiang
# Processing Record 3 of Set 5 | rassvet
# Processing Record 4 of Set 5 | yumen
# Processing Record 5 of Set 5 | eyl
# Processing Record 6 of Set 5 | surin
# Processing Record 7 of Set 5 | imeni poliny osipenko
# Processing Record 8 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 9 of Set 5 | kamaishi
# Processing Record 10 of Set 5 | kenai
# Processing Record 11 of Set 5 | saint-joseph
# Processing Record 12 of Set 5 | andzhiyevskiy
# Processing Record 13 of Set 5 | poronaysk
# Processing Record 14 of Set 5 | san patricio
# Processing Record 15 of Set 5 | charters towers
# Processing Record 16 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 5 | vega de alatorre
# Processing Record 18 of Set 5 | rurrenabaque
# Processing Record 19 of Set 5 | daru
# Processing Record 20 of Set 5 | gornopravdinsk
# Processing Record 21 of Set 5 | mount gambier
# Processing Record 22 of Set 5 | catio
# Processing Record 23 of Set 5 | sant julia de loria
# Processing Record 24 of Set 5 | westport
# Processing Record 25 of Set 5 | pokhara
# Processing Record 26 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 5 | foz
# Processing Record 28 of Set 5 | port alfred
# Processing Record 29 of Set 5 | krasnogorskoye
# Processing Record 30 of Set 5 | sorong
# Processing Record 31 of Set 5 | robertsport
# Processing Record 32 of Set 5 | basco
# Processing Record 33 of Set 5 | kinkala
# Processing Record 34 of Set 5 | valdemarpils
# Processing Record 35 of Set 5 | tura
# Processing Record 36 of Set 5 | dikson
# Processing Record 37 of Set 5 | usevya
# Processing Record 38 of Set 5 | bell ville
# Processing Record 39 of Set 5 | diu
# Processing Record 40 of Set 5 | sao jose da coroa grande
# Processing Record 41 of Set 5 | lompoc
# Processing Record 42 of Set 5 | haapiti
# Processing Record 43 of Set 5 | cockburn town
# Processing Record 44 of Set 5 | kandrian
# Processing Record 45 of Set 5 | iwanai
# Processing Record 46 of Set 5 | zhaoyuan
# Processing Record 47 of Set 5 | mantua
# Processing Record 48 of Set 5 | manokwari
# Processing Record 49 of Set 5 | the valley
# Processing Record 50 of Set 5 | stykkisholmur
# Processing Record 1 of Set 6 | kirakira
# Processing Record 2 of Set 6 | bilibino
# Processing Record 3 of Set 6 | husavik
# Processing Record 4 of Set 6 | lata
# Processing Record 5 of Set 6 | maragogi
# Processing Record 6 of Set 6 | kiruna
# Processing Record 7 of Set 6 | otradnoye
# Processing Record 8 of Set 6 | bundaberg
# Processing Record 9 of Set 6 | araouane
# Processing Record 10 of Set 6 | tarakan
# Processing Record 11 of Set 6 | taitung
# Processing Record 12 of Set 6 | mezen
# Processing Record 13 of Set 6 | vasterhaninge
# Processing Record 14 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 6 | ginir
# Processing Record 16 of Set 6 | eidfjord
# Processing Record 17 of Set 6 | nova soure
# Processing Record 18 of Set 6 | maxixe
# Processing Record 19 of Set 6 | la paz
# Processing Record 20 of Set 6 | manavalakurichi
# Processing Record 21 of Set 6 | gambiran
# Processing Record 22 of Set 6 | avera
# Processing Record 23 of Set 6 | souillac
# Processing Record 24 of Set 6 | saint anthony
# Processing Record 25 of Set 6 | ahvaz
# Processing Record 26 of Set 6 | chunskiy
# Processing Record 27 of Set 6 | itamaraca
# Processing Record 28 of Set 6 | khatanga
# Processing Record 29 of Set 6 | ilulissat
# Processing Record 30 of Set 6 | san martin
# Processing Record 31 of Set 6 | itaituba
# Processing Record 32 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 33 of Set 6 | hovd
# Processing Record 34 of Set 6 | ngorongoro
# Processing Record 35 of Set 6 | coahuayana
# Processing Record 36 of Set 6 | huangmei
# Processing Record 37 of Set 6 | rancho palos verdes
# Processing Record 38 of Set 6 | hithadhoo
# Processing Record 39 of Set 6 | esperance
# Processing Record 40 of Set 6 | ponot
# Processing Record 41 of Set 6 | nome
# Processing Record 42 of Set 6 | savannah bight
# Processing Record 43 of Set 6 | hualmay
# Processing Record 44 of Set 6 | lazaro cardenas
# Processing Record 45 of Set 6 | lorengau
# Processing Record 46 of Set 6 | harper
# Processing Record 47 of Set 6 | lavrentiya
# Processing Record 48 of Set 6 | talnakh
# Processing Record 49 of Set 6 | villa constitucion
# Processing Record 50 of Set 6 | macaubas
# Processing Record 1 of Set 7 | te anau
# Processing Record 2 of Set 7 | trinidad
# Processing Record 3 of Set 7 | pisco
# Processing Record 4 of Set 7 | olinda
# Processing Record 5 of Set 7 | divicani
# Processing Record 6 of Set 7 | kathmandu
# Processing Record 7 of Set 7 | zhaotong
# Processing Record 8 of Set 7 | tingo maria
# Processing Record 9 of Set 7 | ballia
# Processing Record 10 of Set 7 | ewa beach
# Processing Record 11 of Set 7 | shimoda
# Processing Record 12 of Set 7 | bahia blanca
# Processing Record 13 of Set 7 | cap-aux-meules
# Processing Record 14 of Set 7 | abu samrah
# Processing Record 15 of Set 7 | bolgatanga
# Processing Record 16 of Set 7 | konya
# Processing Record 17 of Set 7 | bourg-en-bresse
# Processing Record 18 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 19 of Set 7 | sun prairie
# Processing Record 20 of Set 7 | tomatlan
# Processing Record 21 of Set 7 | oussouye
# Processing Record 22 of Set 7 | bafq
# Processing Record 23 of Set 7 | tazovskiy
# Processing Record 24 of Set 7 | znamenskoye
# Processing Record 25 of Set 7 | sault sainte marie
# Processing Record 26 of Set 7 | port lincoln
# Processing Record 27 of Set 7 | sisimiut
# Processing Record 28 of Set 7 | zhezkazgan
# Processing Record 29 of Set 7 | trairi
# Processing Record 30 of Set 7 | sao paulo de olivenca
# Processing Record 31 of Set 7 | cayenne
# Processing Record 32 of Set 7 | qaqortoq
# Processing Record 33 of Set 7 | gazli
# Processing Record 34 of Set 7 | cartagena
# Processing Record 35 of Set 7 | kisangani
# Processing Record 36 of Set 7 | ponta do sol
# Processing Record 37 of Set 7 | yayva
# Processing Record 38 of Set 7 | praia da vitoria
# Processing Record 39 of Set 7 | koundara
# Processing Record 40 of Set 7 | svetlogorsk
# Processing Record 41 of Set 7 | beloha
# Processing Record 42 of Set 7 | filingue
# Processing Record 43 of Set 7 | mahanoro
# Processing Record 44 of Set 7 | kinshasa
# Processing Record 45 of Set 7 | dingle
# Processing Record 46 of Set 7 | castro
# Processing Record 47 of Set 7 | aligudarz
# Processing Record 48 of Set 7 | arvi
# Processing Record 49 of Set 7 | jijiga
# Processing Record 50 of Set 7 | dekar
# Processing Record 1 of Set 8 | ryotsu
# Processing Record 2 of Set 8 | rodrigues alves
# Processing Record 3 of Set 8 | thinadhoo
# Processing Record 4 of Set 8 | mersing
# Processing Record 5 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 8 | katherine
# Processing Record 7 of Set 8 | salinas
# Processing Record 8 of Set 8 | port-gentil
# Processing Record 9 of Set 8 | port hedland
# Processing Record 10 of Set 8 | kayes
# Processing Record 11 of Set 8 | vestmannaeyjar
# Processing Record 12 of Set 8 | cozumel
# Processing Record 13 of Set 8 | lasa
# Processing Record 14 of Set 8 | namibe
# Processing Record 15 of Set 8 | gombe
# Processing Record 16 of Set 8 | balfour
# Processing Record 17 of Set 8 | sao bras de alportel
# Processing Record 18 of Set 8 | novorzhev
# Processing Record 19 of Set 8 | kingman
# Processing Record 20 of Set 8 | kasane
# Processing Record 21 of Set 8 | shelopugino
# Processing Record 22 of Set 8 | kodiak
# Processing Record 23 of Set 8 | codrington
# Processing Record 24 of Set 8 | vardo
# Processing Record 25 of Set 8 | krasnyy yar
# Processing Record 26 of Set 8 | korla
# Processing Record 27 of Set 8 | zyryanka
# Processing Record 28 of Set 8 | payakumbuh
# Processing Record 29 of Set 8 | kapoeta
# Processing Record 30 of Set 8 | mahibadhoo
# Processing Record 31 of Set 8 | hofn
# Processing Record 32 of Set 8 | grindavik
# Processing Record 33 of Set 8 | mozarlandia
# Processing Record 34 of Set 8 | sao filipe
# Processing Record 35 of Set 8 | high level
# Processing Record 36 of Set 8 | porto velho
# Processing Record 37 of Set 8 | north bend
# Processing Record 38 of Set 8 | brigantine
# Processing Record 39 of Set 8 | buraydah
# Processing Record 40 of Set 8 | abbeville
# Processing Record 41 of Set 8 | los llanos de aridane
# Processing Record 42 of Set 8 | mogochin
# City not found. Skipping...
# Processing Record 43 of Set 8 | snezhnogorsk
# Processing Record 44 of Set 8 | narsaq
# Processing Record 45 of Set 8 | andros town
# Processing Record 46 of Set 8 | hami
# Processing Record 47 of Set 8 | samarai
# Processing Record 48 of Set 8 | sitka
# Processing Record 49 of Set 8 | kulai
# Processing Record 50 of Set 8 | opuwo
# Processing Record 1 of Set 9 | muncar
# Processing Record 2 of Set 9 | ostersund
# Processing Record 3 of Set 9 | creel
# Processing Record 4 of Set 9 | norden
# Processing Record 5 of Set 9 | guhagar
# Processing Record 6 of Set 9 | hay river
# Processing Record 7 of Set 9 | foumban
# Processing Record 8 of Set 9 | santa rosa
# Processing Record 9 of Set 9 | haines junction
# Processing Record 10 of Set 9 | malakal
# Processing Record 11 of Set 9 | kidodi
# Processing Record 12 of Set 9 | dali
# Processing Record 13 of Set 9 | belyy yar
# Processing Record 14 of Set 9 | fort nelson
# Processing Record 15 of Set 9 | klaeng
# Processing Record 16 of Set 9 | ozernovskiy
# Processing Record 17 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 18 of Set 9 | mayumba
# Processing Record 19 of Set 9 | healesville
# Processing Record 20 of Set 9 | mount isa
# Processing Record 21 of Set 9 | colares
# Processing Record 22 of Set 9 | inhambane
# Processing Record 23 of Set 9 | deh rawud
# City not found. Skipping...
# Processing Record 24 of Set 9 | misawa
# Processing Record 25 of Set 9 | alyangula
# Processing Record 26 of Set 9 | aswan
# Processing Record 27 of Set 9 | ostrovnoy
# Processing Record 28 of Set 9 | isangel
# Processing Record 29 of Set 9 | bagnes
# Processing Record 30 of Set 9 | bambous virieux
# Processing Record 31 of Set 9 | ponta delgada
# Processing Record 32 of Set 9 | tautira
# Processing Record 33 of Set 9 | loa janan
# Processing Record 34 of Set 9 | collie
# Processing Record 35 of Set 9 | yialos
# City not found. Skipping...
# Processing Record 36 of Set 9 | fort saint james
# Processing Record 37 of Set 9 | hope
# Processing Record 38 of Set 9 | itapecerica
# Processing Record 39 of Set 9 | goroka
# Processing Record 40 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 41 of Set 9 | vavuniya
# Processing Record 42 of Set 9 | quimper
# Processing Record 43 of Set 9 | riyadh
# Processing Record 44 of Set 9 | wangkui
# Processing Record 45 of Set 9 | ovalle
# Processing Record 46 of Set 9 | siocon
# Processing Record 47 of Set 9 | muros
# Processing Record 48 of Set 9 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 49 of Set 9 | kawhia
# Processing Record 50 of Set 9 | tocopilla
# Processing Record 1 of Set 10 | mackay
# Processing Record 2 of Set 10 | ust-nera
# Processing Record 3 of Set 10 | bridlington
# Processing Record 4 of Set 10 | yermakovskoye
# Processing Record 5 of Set 10 | parakai
# Processing Record 6 of Set 10 | santa vitoria
# Processing Record 7 of Set 10 | chopovychi
# Processing Record 8 of Set 10 | ngunguru
# Processing Record 9 of Set 10 | shenjiamen
# Processing Record 10 of Set 10 | buala
# Processing Record 11 of Set 10 | flin flon
# Processing Record 12 of Set 10 | gainesville
# Processing Record 13 of Set 10 | nouadhibou
# Processing Record 14 of Set 10 | alihe
# Processing Record 15 of Set 10 | nelson bay
# Processing Record 16 of Set 10 | half moon bay
# Processing Record 17 of Set 10 | nola
# Processing Record 18 of Set 10 | shalinskoye
# Processing Record 19 of Set 10 | chekhov
# Processing Record 20 of Set 10 | elizabeth city
# Processing Record 21 of Set 10 | vestmanna
# Processing Record 22 of Set 10 | marawi
# Processing Record 23 of Set 10 | aksu
# Processing Record 24 of Set 10 | ambulu
# Processing Record 25 of Set 10 | saquena
# Processing Record 26 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 10 | saint-augustin
# Processing Record 28 of Set 10 | the pas
# Processing Record 29 of Set 10 | mahajanga
# Processing Record 30 of Set 10 | saint-pierre
# Processing Record 31 of Set 10 | poltavka
# Processing Record 32 of Set 10 | fairbanks
# Processing Record 33 of Set 10 | srednekolymsk
# Processing Record 34 of Set 10 | quatre cocos
# Processing Record 35 of Set 10 | brae
# Processing Record 36 of Set 10 | kavaratti
# Processing Record 37 of Set 10 | martapura
# Processing Record 38 of Set 10 | smithers
# Processing Record 39 of Set 10 | alta floresta
# Processing Record 40 of Set 10 | sao gabriel da cachoeira
# Processing Record 41 of Set 10 | kulhudhuffushi
# Processing Record 42 of Set 10 | tommot
# Processing Record 43 of Set 10 | tabou
# Processing Record 44 of Set 10 | general roca
# Processing Record 45 of Set 10 | san angelo
# Processing Record 46 of Set 10 | polyarnyy
# Processing Record 47 of Set 10 | virginia beach
# Processing Record 48 of Set 10 | goderich
# Processing Record 49 of Set 10 | morondava
# Processing Record 50 of Set 10 | berlevag
# Processing Record 1 of Set 11 | workington
# Processing Record 2 of Set 11 | canakkale
# Processing Record 3 of Set 11 | severobaykalsk
# Processing Record 4 of Set 11 | paamiut
# Processing Record 5 of Set 11 | la tuque
# Processing Record 6 of Set 11 | kitami
# Processing Record 7 of Set 11 | muisne
# Processing Record 8 of Set 11 | labuhan
# Processing Record 9 of Set 11 | deputatskiy
# Processing Record 10 of Set 11 | mocajuba
# Processing Record 11 of Set 11 | kushmurun
# Processing Record 12 of Set 11 | saldanha
# Processing Record 13 of Set 11 | udachnyy
# Processing Record 14 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 11 | puteyets
# Processing Record 16 of Set 11 | luneville
# Processing Record 17 of Set 11 | nisia floresta
# Processing Record 18 of Set 11 | russell
# Processing Record 19 of Set 11 | manaus
# Processing Record 20 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 11 | holme
# Processing Record 22 of Set 11 | southwick
# Processing Record 23 of Set 11 | bourail
# Processing Record 24 of Set 11 | qasigiannguit
# Processing Record 25 of Set 11 | luganville
# Processing Record 26 of Set 11 | talavera
# Processing Record 27 of Set 11 | timra
# Processing Record 28 of Set 11 | eregli
# Processing Record 29 of Set 11 | batagay
# Processing Record 30 of Set 11 | sorgun
# Processing Record 31 of Set 11 | yaan
# Processing Record 32 of Set 11 | juegang
# Processing Record 33 of Set 11 | kapuskasing
# Processing Record 34 of Set 11 | rio gallegos
# Processing Record 35 of Set 11 | pacific grove
# Processing Record 36 of Set 11 | la rioja
# Processing Record 37 of Set 11 | cururupu
# Processing Record 38 of Set 11 | irbil
# Processing Record 39 of Set 11 | laguna
# Processing Record 40 of Set 11 | rapid valley
# Processing Record 41 of Set 11 | carutapera
# Processing Record 42 of Set 11 | roma
# Processing Record 43 of Set 11 | sinegorye
# Processing Record 44 of Set 11 | plouzane
# Processing Record 45 of Set 11 | carlos chagas
# Processing Record 46 of Set 11 | bria
# Processing Record 47 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 11 | zaragoza
# Processing Record 49 of Set 11 | mareeba
# Processing Record 50 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 1 of Set 12 | nurota
# Processing Record 2 of Set 12 | kirkwall
# Processing Record 3 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 4 of Set 12 | vila velha
# Processing Record 5 of Set 12 | konevo
# Processing Record 6 of Set 12 | mae sai
# Processing Record 7 of Set 12 | sao joao do piaui
# Processing Record 8 of Set 12 | roald
# Processing Record 9 of Set 12 | kearney
# Processing Record 10 of Set 12 | west wendover
# Processing Record 11 of Set 12 | visalia
# Processing Record 12 of Set 12 | katangli
# Processing Record 13 of Set 12 | nordborg
# Processing Record 14 of Set 12 | chapadinha
# Processing Record 15 of Set 12 | sehithwa
# Processing Record 16 of Set 12 | sangar
# Processing Record 17 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 18 of Set 12 | meulaboh
# Processing Record 19 of Set 12 | ataco
# Processing Record 20 of Set 12 | la asuncion
# Processing Record 21 of Set 12 | whitehorse
# Processing Record 22 of Set 12 | erdenet
# Processing Record 23 of Set 12 | port keats
# Processing Record 24 of Set 12 | nanakuli
# Processing Record 25 of Set 12 | festus
# Processing Record 26 of Set 12 | san quintin
# Processing Record 27 of Set 12 | sishui
# Processing Record 28 of Set 12 | mindelo
# Processing Record 29 of Set 12 | annau
# Processing Record 30 of Set 12 | morro bay
# Processing Record 31 of Set 12 | grand gaube
# Processing Record 32 of Set 12 | grand island
# Processing Record 33 of Set 12 | butembo
# Processing Record 34 of Set 12 | energetik
# Processing Record 35 of Set 12 | ahuimanu
# Processing Record 36 of Set 12 | southbridge
# Processing Record 37 of Set 12 | chandia
# Processing Record 38 of Set 12 | vershino-shakhtaminskiy
# Processing Record 39 of Set 12 | sorland
# Processing Record 40 of Set 12 | bergen
# Processing Record 41 of Set 12 | juneau
# Processing Record 42 of Set 12 | henties bay
# Processing Record 43 of Set 12 | san carlos de bariloche
# Processing Record 44 of Set 12 | ust-ilimsk
# Processing Record 45 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 12 | borzya
# Processing Record 47 of Set 12 | albanel
# Processing Record 48 of Set 12 | magole
# Processing Record 49 of Set 12 | namatanai
# Processing Record 50 of Set 12 | tiarei
# Processing Record 1 of Set 13 | jumla
# Processing Record 2 of Set 13 | gorontalo
# Processing Record 3 of Set 13 | si racha
# Processing Record 4 of Set 13 | kemijarvi
# Processing Record 5 of Set 13 | tripoli
# Processing Record 6 of Set 13 | paveh
# Processing Record 7 of Set 13 | brownsville
# Processing Record 8 of Set 13 | winchester
# Processing Record 9 of Set 13 | clyde river
# Processing Record 10 of Set 13 | cape elizabeth
# City not found. Skipping...
# Processing Record 11 of Set 13 | parung
# Processing Record 12 of Set 13 | ossora
# Processing Record 13 of Set 13 | assiniboia
# Processing Record 14 of Set 13 | arica
# Processing Record 15 of Set 13 | marzuq
# Processing Record 16 of Set 13 | meiganga
# Processing Record 17 of Set 13 | kismayo
# Processing Record 18 of Set 13 | arvika
# Processing Record 19 of Set 13 | hastings
# Processing Record 20 of Set 13 | taoudenni
# Processing Record 21 of Set 13 | luangwa
# Processing Record 22 of Set 13 | abu dhabi
# Processing Record 23 of Set 13 | gobabis
# Processing Record 24 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 25 of Set 13 | baksanenok
# Processing Record 26 of Set 13 | san andres
# Processing Record 27 of Set 13 | george
# Processing Record 28 of Set 13 | saraland
# Processing Record 29 of Set 13 | bintulu
# Processing Record 30 of Set 13 | kattivakkam
# Processing Record 31 of Set 13 | palmer
# Processing Record 32 of Set 13 | katsuura
# Processing Record 33 of Set 13 | arona
# Processing Record 34 of Set 13 | dipkarpaz
# City not found. Skipping...
# Processing Record 35 of Set 13 | sechura
# Processing Record 36 of Set 13 | xuddur
# Processing Record 37 of Set 13 | mao
# Processing Record 38 of Set 13 | stokmarknes
# Processing Record 39 of Set 13 | alofi
# Processing Record 40 of Set 13 | nkayi
# Processing Record 41 of Set 13 | banda aceh
# Processing Record 42 of Set 13 | griffith
# Processing Record 43 of Set 13 | lingao
# Processing Record 44 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 13 | hohhot
# Processing Record 46 of Set 13 | muromtsevo
# Processing Record 47 of Set 13 | sibolga
# Processing Record 48 of Set 13 | kondopoga
# Processing Record 49 of Set 13 | faro
# Processing Record 50 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 14 | matamoros
# Processing Record 2 of Set 14 | jiangyou
# Processing Record 3 of Set 14 | kahului
# Processing Record 4 of Set 14 | lahat
# Processing Record 5 of Set 14 | naze
# Processing Record 6 of Set 14 | freeport
# Processing Record 7 of Set 14 | lagunas
# Processing Record 8 of Set 14 | moron
# Processing Record 9 of Set 14 | oga
# Processing Record 10 of Set 14 | honningsvag
# Processing Record 11 of Set 14 | changping
# Processing Record 12 of Set 14 | burley
# Processing Record 13 of Set 14 | mudyuga
# City not found. Skipping...
# Processing Record 14 of Set 14 | seydisehir
# Processing Record 15 of Set 14 | kampot
# Processing Record 16 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 17 of Set 14 | zhanaozen
# Processing Record 18 of Set 14 | kikwit
# Processing Record 19 of Set 14 | diamantino
# Processing Record 20 of Set 14 | hue
# Processing Record 21 of Set 14 | gemena
# Processing Record 22 of Set 14 | bayir
# Processing Record 23 of Set 14 | jvari
# Processing Record 24 of Set 14 | kasongo-lunda
# Processing Record 25 of Set 14 | bentiu
# Processing Record 26 of Set 14 | marv dasht
# City not found. Skipping...
# Processing Record 27 of Set 14 | cuamba
# Processing Record 28 of Set 14 | tarifa
# Processing Record 29 of Set 14 | tiebissou
# Processing Record 30 of Set 14 | leshukonskoye
# Processing Record 31 of Set 14 | hangu
# Processing Record 32 of Set 14 | zaraza
# Processing Record 33 of Set 14 | mehamn
# Processing Record 34 of Set 14 | ketchikan
# Processing Record 35 of Set 14 | marbella
# Processing Record 36 of Set 14 | miyako
# Processing Record 37 of Set 14 | birin
# Processing Record 38 of Set 14 | pimentel
# Processing Record 39 of Set 14 | yerbogachen
# Processing Record 40 of Set 14 | hounde
# Processing Record 41 of Set 14 | doha
# Processing Record 42 of Set 14 | seoul
# Processing Record 43 of Set 14 | black diamond
# Processing Record 44 of Set 14 | hobyo
# Processing Record 45 of Set 14 | krasnoturinsk
# Processing Record 46 of Set 14 | sistranda
# Processing Record 47 of Set 14 | kamskiye polyany
# Processing Record 48 of Set 14 | maroantsetra
# Processing Record 49 of Set 14 | warsaw
# Processing Record 50 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 1 of Set 15 | dordrecht
# Processing Record 2 of Set 15 | marsabit
# Processing Record 3 of Set 15 | qui nhon
# Processing Record 4 of Set 15 | krasnoselkup
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %%
len(city_data)
# Out:
# 699

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Punta Arenas -53.15  -70.92     50.00        87         100        4.70
# 1          Mongo  12.18   18.69     73.53        25           0        4.23
# 2     Nikolskoye  59.70   30.79     23.00        92          75        4.47
# 3  Mar Del Plata -38.00  -57.56     66.99        93          75        9.17
# 4           Beya  53.05   90.91    -10.05        84          96        2.48
# 5    Yellowknife  62.46 -114.35    -11.20        83          90        6.93
# 6        Ushuaia -54.80  -68.30     46.40        87          75       12.75
# 7     Bredasdorp -34.53   20.04     64.40        72          99       11.41
# 8        Kavieng  -2.57  150.80     85.62        66          14        9.86
# 9      Coihaique -45.58  -72.07     54.36        87         100        4.05
#
#   Country Current Description
# 0      CL       moderate rain
# 1      TD           clear sky
# 2      RU       broken clouds
# 3      AR       broken clouds
# 4      RU     overcast clouds
# 5      CA          light snow
# 6      AR       broken clouds
# 7      ZA     overcast clouds
# 8      PG          few clouds
# 9      CL     overcast clouds

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# %%
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0   Punta Arenas      CL -53.15  -70.92     50.00        87         100
# 1          Mongo      TD  12.18   18.69     73.53        25           0
# 2     Nikolskoye      RU  59.70   30.79     23.00        92          75
# 3  Mar Del Plata      AR -38.00  -57.56     66.99        93          75
# 4           Beya      RU  53.05   90.91    -10.05        84          96
# 5    Yellowknife      CA  62.46 -114.35    -11.20        83          90
# 6        Ushuaia      AR -54.80  -68.30     46.40        87          75
# 7     Bredasdorp      ZA -34.53   20.04     64.40        72          99
# 8        Kavieng      PG  -2.57  150.80     85.62        66          14
# 9      Coihaique      CL -45.58  -72.07     54.36        87         100
#
#    Wind Speed Current Description
# 0        4.70       moderate rain
# 1        4.23           clear sky
# 2        4.47       broken clouds
# 3        9.17       broken clouds
# 4        2.48     overcast clouds
# 5        6.93          light snow
# 6       12.75       broken clouds
# 7       11.41     overcast clouds
# 8        9.86          few clouds
# 9        4.05     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file,index_label="City_ID")
